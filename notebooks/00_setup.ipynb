# %% [markdown]
# # Notebook 00: Environment Verification
# Verifies dependency compatibility, folder structures, pathing, and default plotting formats.

# %% [markdown]
# ### Important Project Safety Notice
#
# Before executing or citing the findings in this notebook, please read the public guidance on what this project is and is not claiming:
#
# [docs/not_saying.md](../docs/not_saying.md) - *What This Theory Is NOT Claiming*

# %%
import os
import sys
import numpy as np
import pandas as pd
import scipy
import matplotlib
import seaborn as sns
import statsmodels
import linearmodels
import factor_analyzer
import semopy
import mesa
import networkx as nx
import ipywidgets as widgets

print('All core dependencies imported successfully.')
print(f'Python version: {sys.version}')

# %%
# Verify local directory structure
required_dirs = ['../data/raw', '../data/processed', '../src']
for d in required_dirs:
    if os.path.exists(d):
        print(f'Directory verified: {d}')
    else:
        print(f'Missing directory: {d}')
